# %% [markdown]
# Ingestion des données

# %% [markdown]
# Récupération de toutes les colonnes existantes

# %%
import json
import pandas as pd 
import os 
path = '/home/pierre/Documents/DE_DATASCIENTEST/data_projet_dst_airlines/afklm_large/'
files = os.listdir(path)
total_departure_columns = []
total_arrival_columns = []
total_codeShareRelations_columns = []

for i in range(100):
    file_= files[i]
    print(file_)
    try:
        with open(f"{path}/{file_}", 'r') as file:
            data = json.load(file)
            df = pd.json_normalize(data['operationalFlights'])
            departure_columns = df.flightLegs.apply(lambda x: pd.json_normalize(x[0]["departureInformation"]).columns.to_list())
            total_departure_columns.extend(list(set(departure_columns.explode().to_list())))
            arrival_columns = df.flightLegs.apply(lambda x: pd.json_normalize(x[0]["arrivalInformation"]).columns.to_list())
            total_arrival_columns.extend(list(set(arrival_columns.explode().to_list())))

            codeShareRelations_columns = df.loc[-df.codeShareRelations.isna()].codeShareRelations.explode().apply(lambda x: x.keys())
            total_codeShareRelations_columns.extend(list(set(codeShareRelations_columns.explode().to_list())))

    except:
        pass
total_departure_columns = list(set(total_departure_columns))
total_arrival_columns = list(set(total_arrival_columns))
total_codeShareRelations_columns = list(set(total_codeShareRelations_columns))
# Out:
# AFKLM_get_flight_2026_01_30_2026_01_31_page_38.json
# AFKLM_get_flight_2026_01_17_2026_01_18_page_76.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_43.json
# AFKLM_get_flight_2026_01_15_2026_01_16_page_45.json
# AFKLM_get_flight_2026_01_28_2026_01_29_page_41.json
# AFKLM_get_flight_2026_01_11_2026_01_12_page_44.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_38.json
# AFKLM_get_flight_2026_01_22_2026_01_23_page_98.json
# AFKLM_get_flight_2026_01_21_2026_01_22_page_12.json
# AFKLM_get_flight_2026_01_18_2026_01_19_page_41.json
# AFKLM_get_flight_2026_01_22_2026_01_23_page_60.json
# AFKLM_get_flight_2026_01_08_2026_01_09_page_5.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_48.json
# AFKLM_get_flight_2026_01_21_2026_01_22_page_44.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_52.json
# AFKLM_get_flight_2026_01_23_2026_01_24_page_83.json
# AFKLM_get_flight_2026_01_29_2026_01_30_page_44.json
# AFKLM_get_flight_2026_01_14_2026_01_15_page_73.json
# AFKLM_get_flight_2026_01_31_2026_02_01_page_12.json
# AFKLM_get_flight_2026_01_28_2026_01_29_page_30.json
# AFKLM_get_flight_2026_01_30_2026_01_31_page_64.json
# AFKLM_get_flight_2026_01_12_2026_01_13_page_40.json
# AFKLM_get_flight_2026_01_15_2026_01_16_page_5.json
# AFKLM_get_flight_2026_01_11_2026_01_12_page_11.json
# AFKLM_get_flight_2026_01_07_2026_01_08_page_57.json
# AFKLM_get_flight_2026_01_12_2026_01_13_page_17.json
# AFKLM_get_flight_2026_01_11_2026_01_12_page_1.json
# AFKLM_get_flight_2026_01_18_2026_01_19_page_38.json
# AFKLM_get_flight_2026_01_23_2026_01_24_page_37.json
# AFKLM_get_flight_2026_01_10_2026_01_11_page_45.json
# AFKLM_get_flight_2026_01_22_2026_01_23_page_58.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_74.json
# AFKLM_get_flight_2026_01_30_2026_01_31_page_17.json
# AFKLM_get_flight_2026_01_21_2026_01_22_page_60.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_6.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_85.json
# AFKLM_get_flight_2026_01_15_2026_01_16_page_9.json
# AFKLM_get_flight_2026_01_07_2026_01_08_page_49.json
# AFKLM_get_flight_2026_01_18_2026_01_19_page_59.json
# AFKLM_get_flight_2026_01_29_2026_01_30_page_57.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_9.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_60.json
# AFKLM_get_flight_2026_01_21_2026_01_22_page_83.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_60.json
# AFKLM_get_flight_2026_01_22_2026_01_23_page_62.json
# AFKLM_get_flight_2026_01_07_2026_01_08_page_44.json
# AFKLM_get_flight_2026_01_07_2026_01_08_page_17.json
# AFKLM_get_flight_2026_01_01_2026_01_02_page_69.json
# AFKLM_get_flight_2026_01_30_2026_01_31_page_24.json
# AFKLM_get_flight_2026_01_30_2026_01_31_page_6.json
# AFKLM_get_flight_2026_01_14_2026_01_15_page_42.json
# AFKLM_get_flight_2026_01_02_2026_01_03_page_19.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_54.json
# AFKLM_get_flight_2026_01_07_2026_01_08_page_54.json
# AFKLM_get_flight_2026_01_10_2026_01_11_page_6.json
# AFKLM_get_flight_2026_01_02_2026_01_03_page_6.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_15.json
# AFKLM_get_flight_2026_01_18_2026_01_19_page_0.json
# AFKLM_get_flight_2026_01_30_2026_01_31_page_12.json
# AFKLM_get_flight_2026_01_31_2026_02_01_page_32.json
# AFKLM_get_flight_2026_01_12_2026_01_13_page_38.json
# AFKLM_get_flight_2026_01_13_2026_01_14_page_18.json
# AFKLM_get_flight_2026_01_15_2026_01_16_page_57.json
# AFKLM_get_flight_2026_01_17_2026_01_18_page_77.json
# AFKLM_get_flight_2026_01_01_2026_01_02_page_63.json
# AFKLM_get_flight_2026_01_13_2026_01_14_page_76.json
# AFKLM_get_flight_2026_01_28_2026_01_29_page_37.json
# AFKLM_get_flight_2026_01_22_2026_01_23_page_52.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_23.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_69.json
# AFKLM_get_flight_2026_01_18_2026_01_19_page_43.json
# AFKLM_get_flight_2026_01_14_2026_01_15_page_32.json
# AFKLM_get_flight_2026_01_23_2026_01_24_page_42.json
# AFKLM_get_flight_2026_01_31_2026_02_01_page_33.json
# AFKLM_get_flight_2026_01_17_2026_01_18_page_30.json
# AFKLM_get_flight_2026_01_08_2026_01_09_page_1.json
# AFKLM_get_flight_2026_01_21_2026_01_22_page_0.json
# AFKLM_get_flight_2026_01_11_2026_01_12_page_66.json
# AFKLM_get_flight_2026_01_08_2026_01_09_page_56.json
# AFKLM_get_flight_2026_01_31_2026_02_01_page_5.json
# AFKLM_get_flight_2026_01_31_2026_02_01_page_34.json
# AFKLM_get_flight_2026_01_21_2026_01_22_page_8.json
# AFKLM_get_flight_2026_01_13_2026_01_14_page_19.json
# AFKLM_get_flight_2026_01_11_2026_01_12_page_16.json
# AFKLM_get_flight_2026_01_29_2026_01_30_page_79.json
# AFKLM_get_flight_2026_01_30_2026_01_31_page_52.json
# AFKLM_get_flight_2026_01_21_2026_01_22_page_68.json
# AFKLM_get_flight_2026_01_01_2026_01_02_page_16.json
# AFKLM_get_flight_2026_01_08_2026_01_09_page_35.json
# AFKLM_get_flight_2026_01_23_2026_01_24_page_51.json
# AFKLM_get_flight_2026_01_14_2026_01_15_page_3.json
# AFKLM_get_flight_2026_01_28_2026_01_29_page_82.json
# AFKLM_get_flight_2026_01_18_2026_01_19_page_30.json
# AFKLM_get_flight_2026_01_08_2026_01_09_page_12.json
# AFKLM_get_flight_2026_01_02_2026_01_03_page_16.json
# AFKLM_get_flight_2026_01_09_2026_01_10_page_75.json
# AFKLM_get_flight_2026_01_10_2026_01_11_page_23.json
# AFKLM_get_flight_2026_01_23_2026_01_24_page_66.json
# AFKLM_get_flight_2026_01_19_2026_01_20_page_61.json
# AFKLM_get_flight_2026_01_13_2026_01_14_page_51.json

# %%
# Colonnes qui doivent être présentes dans les json 
necessary_columns = {"flight":["flightId","airline.code","flightNumber"],
                    "scheduledFlight" : ['scheduledFlightId','flightNumber','flightScheduleDate','haul','route','flightStatusPublic','airline.code'],
                    "codeShareRelation": ["codeShareId" , "flightId","relatedFlightId"],
                    "flightRelation": ["flightRelationId","scheduledFlightId","relatedScheduledFlightId","relationType"],
                    "flightLeg":["flightLegId",
            "scheduledFlightId",
            "legStatusPublicLangTransl",
            "statusName",
            "passengerCustomsStatus",
            "serviceType",
            "serviceTypeName",
            "restricted",
            "scheduledFlightDuration",
            "departureDateTimeDifference",
            "arrivalDateTimeDifference",
            "timeToArrival",
            "completionPercentage",
            "timeZoneDifference",
            "aircraft.typeCode",
            "DepartureInformation.airport.places.aerogareCode", 
            "DepartureInformation.airport.places.gateNumber" ,
            "DepartureInformation.airport.places.parkingPosition" ,
            "DepartureInformation.airport.places.parkingPositionCustomStatus", 
            "DepartureInformation.airport.places.parkingPositionType", 
            "DepartureInformation.airport.places.pierCode" ,
            "DepartureInformation.airport.places.terminalCode", 
            "DepartureInformation.airport.code" ,
            "DepartureInformation.times.actual" ,
            "DepartureInformation.times.latestPublished", 
            "DepartureInformation.times.modified",
            "DepartureInformation.times.scheduled" ,
            "DepartureInformation.airport.places.boardingContactType", 
            "DepartureInformation.airport.places.boardingPier ",
            "DepartureInformation.airport.places.boardingTerminal", 
            "DepartureInformation.airport.places.checkInAerogare", 
            "DepartureInformation.airport.places.checkInZone", 
            "DepartureInformation.airport.places.departureTerminal" ,
            "DepartureInformation.airport.places.paxDepartureGate" ,
            "DepartureInformation.boardingTimes.actualBoardingOpen", 
            "DepartureInformation.boardingTimes.firstPaxBoarding", 
            "DepartureInformation.boardingTimes.gateCloseTime" ,
            "DepartureInformation.boardingTimes.plannedBoardingTime", 
            "DepartureInformation.times.actualTakeOffTime", 
            "DepartureInformation.times.estimatedPublic" ,
            "DepartureInformation.times.estimatedTakeOffTime",
            "arrivalInformation.airport.places.aerogareCode", 
            "arrivalInformation.airport.places.gateNumber" ,
            "arrivalInformation.airport.places.parkingPosition" ,
            "arrivalInformation.airport.places.parkingPositionCustomStatus", 
            "arrivalInformation.airport.places.parkingPositionType", 
            "arrivalInformation.airport.places.pierCode" ,
            "arrivalInformation.airport.places.terminalCode" ,
            "arrivalInformation.airport.code" ,
            "arrivalInformation.times.actual" ,
            "arrivalInformation.times.latestPublished", 
            "arrivalInformation.times.modified" ,
            "arrivalInformation.times.scheduled", 
            "arrivalInformation.airport.places.arrivalHall" ,
            "arrivalInformation.airport.places.arrivalPositionPier" ,
            "arrivalInformation.airport.places.arrivalPositionTerminal", 
            "arrivalInformation.airport.places.arrivalTerminal" ,
            "arrivalInformation.airport.places.baggageBelt" ,
            "arrivalInformation.airport.places.disembarkingAerogare" ,
            "arrivalInformation.airport.places.disembarkingBusQuantity" ,
            "arrivalInformation.airport.places.disembarkingContactType", 
            "arrivalInformation.airport.places.expectedBagOnBeltTime", 
            "arrivalInformation.airport.places.firstBagOnBeltTime" ,
            "arrivalInformation.airport.places.lastBagOnBeltTime" ,
            "arrivalInformation.times.actualTouchDownTime" ,
            "arrivalInformation.times.estimated.value" ,
            "arrivalInformation.times.estimatedArrival" ,
            "arrivalInformation.times.estimatedTouchDownTime"],

            "airport":[    "departureInformation.airport.code",
                "departureInformation.airport.name",
                "departureInformation.airport.location.latitude",
                "departureInformation.airport.location.longitude",
                "departureInformation.airport.city.code",    "arrivalInformation.airport.code",
                "arrivalInformation.airport.name",
                "arrivalInformation.airport.location.latitude",
                "arrivalInformation.airport.location.longitude",
                "arrivalInformation.airport.city.code" ],

            "city": [    "departureInformation.airport.city.code",
    "departureInformation.airport.city.name",
    "departureInformation.airport.city.country.code",        "arrivalInformation.airport.city.code",
    "arrivalInformation.airport.city.name",
    "arrivalInformation.airport.city.country.code"],
    "country":[    "departureInformation.airport.city.country.code",
    "departureInformation.airport.city.country.name",
"departureInformation.airport.city.country.euroCountry",
   "departureInformation.airport.city.country.euCountry",
   "departureInformation.airport.city.country.areaCode",    "arrivalInformation.airport.city.country.code",
    "arrivalInformation.airport.city.country.name",
"arrivalInformation.airport.city.country.euroCountry",
   "arrivalInformation.airport.city.country.euCountry",
   "arrivalInformation.airport.city.country.areaCode"],

   'aircraft': [
"aircraft.typeCode",
"aircraft.typeName",
"aircraft.ownerAirlineCode",
"aircraft.physicalPaxConfiguration",
"aircraft.physicalFreightConfiguration",
"aircraft.operationalConfiguration",
"aircraft.cockpitCrewEmployer",
"aircraft.cabinCrewEmployer",
"aircraft.registration",
"aircraft.saleableConfiguration",
"aircraft.subFleetCodeId",
"aircraft.typeCode",
"aircraft.typeName"
],
"irregularity":["flightLegId",
                "irregularity.cancelled",
                "irregularity.cancellationReasonCodePublic",
                "irregularity.delayCode",
                "irregularity.delayDuration"],
"delay":["irregularity.delayCode",
         "irregularity.delayReasonCodePublic"],
 "cancellationReason":["irregularity.cancellationReasonCodePublic",
                       "irregularity.cancellationReasonPublicShort",
                       "irregularity.cancellationReasonPublicLong"],
"delayReason":["irregularity.delayReasonCodePublic", 
                "irregularity.delayReasonPublicLangTransl"]
}

# %%
import json

def to_json(dictionary, filename):
    with open(filename,'w') as fp:
        json.dump(dictionary, fp,sort_keys=True, indent=4,ensure_ascii=False)
to_json(necessary_columns, "necessary_columns.json")
with open('necessary_columns.json') as json_file:
    necessary_columns = json.load(json_file)
necessary_columns

# %%
import os 
os.getcwd()
# Out:
# '/home/pierre/Documents/DE_DATASCIENTEST/dst_airlines/1_ingestion'

# %%
def add_missing_columns(df, table):
    nc_ = necessary_columns[table] # récupère les colonnes obligatoires 

    missing_cols_ = list(set(nc_) - set(df.columns)) # récupère les missing 
    
    if len(missing_cols_)>0:
        df_missing_columns = pd.DataFrame({c: pd.Series() for c in missing_cols_}) # ajoute autant de colonnes vides 
        df = pd.concat([df, df_missing_columns]) # bind 
    return df 

# usage: df = add_missing_columns(df, "aircraft")

# %%
# Load a file for dev

import json
import pandas as pd 
import os 
path = '/home/pierre/Documents/DE_DATASCIENTEST/data_projet_dst_airlines/afklm_large/'
files = os.listdir(path)
file_ = files[6]
with open(f"{path}/{file_}", 'r') as file:
    data = json.load(file)
    print(data['operationalFlights'])
    data = data['operationalFlights']
    df = pd.json_normalize(data)
    df["flightId"] = df["airline.code"] + "+" + df["flightNumber"].astype(str) # créé le flightID
    df = df.rename(columns={"id":"scheduledFlightId"})
    print(df.columns)
# Out:
# [{'flightNumber': 704, 'flightScheduleDate': '2026-01-09', 'id': '20260109+RO+0704', 'route': ['IAS', 'OTP'], 'airline': {'code': 'RO', 'name': 'TAROM'}, 'codeShareRelations': [{'marketingFlightNumber': 2739, 'airline': {'code': 'KL', 'name': 'KLM ROYAL DUTCH AIRLINES'}}, {'marketingFlightNumber': 9534, 'airline': {'code': 'LY', 'name': 'EL AL ISRAEL AIRLINES LTD.'}}, {'marketingFlightNumber': 9049, 'airline': {'code': 'TK', 'name': 'TURKISH AIRLINES INC.'}}], 'flightRelations': {'previousFlightData': {'id': '20260108+RO+0707', 'flightScheduleDate': '2026-01-08', 'airlineCode': 'RO', 'flightNumber': '0707'}}, 'flightStatusPublic': 'ARRIVED', 'flightStatusPublicLangTransl': 'Arrived', 'flightLegs': [{'publishedStatus': 'ARRIVED', 'departureInformation': {'airport': {'code': 'IAS', 'name': 'IASI AIRPORT', 'nameLangTranl': 'Iaşi Airport', 'city': {'code': 'IAS', 'name': 'IASI', 'nameLangTranl': 'Iasi', 'country': {'areaCode': 'E', 'code': 'RO', 'name': 'ROMANIA', 'nameLangTranl': 'Romania', 'euroCountry': 'N', 'euCountry': 'Y'}}, 'location': {'latitude': 47.1833, 'longitude': 27.6}, 'places': {'gateNumber': [], 'terminalCode': '4', 'boardingTerminal': '4', 'checkInZone': [], 'paxDepartureGate': []}}, 'times': {'actual': '2026-01-09T13:40:00.000+02:00', 'scheduled': '2026-01-09T13:50:00.000+02:00', 'latestPublished': '2026-01-09T13:40:00.000+02:00', 'actualTakeOffTime': '2026-01-09T13:49:00.000+02:00'}}, 'arrivalInformation': {'airport': {'code': 'OTP', 'name': 'HENRI COANDA AIRPORT', 'nameLangTranl': 'Henri Coanda International Airport', 'city': {'code': 'BUH', 'name': 'BUCHAREST', 'nameLangTranl': 'Bucharest', 'country': {'areaCode': 'E', 'code': 'RO', 'name': 'ROMANIA', 'nameLangTranl': 'Romania', 'euroCountry': 'N', 'euCountry': 'Y'}}, 'location': {'latitude': 44.5667, 'longitude': 26.1}}, 'times': {'actual': '2026-01-09T14:50:00.000+02:00', 'scheduled': '2026-01-09T15:00:00.000+02:00', 'latestPublished': '2026-01-09T14:50:00.000+02:00', 'estimated': {'value': '2026-01-09T14:50:00.000+02:00'}, 'actualTouchDownTime': '2026-01-09T14:45:00.000+02:00'}}, 'legStatusPublic': 'ARRIVED', 'legStatusPublicLangTransl': 'Arrived', 'passengerCustomsStatus': 'SCHENGEN', 'serviceType': 'J', 'serviceTypeName': 'Normal Service', 'restricted': False, 'scheduledFlightDuration': 'PT1H10M', 'departureDateTimeDifference': 'PT-10M', 'arrivalDateTimeDifference': 'PT-10M', 'timeToArrival': 'PT0S', 'completionPercentage': '100', 'timeZoneDifference': '+0000', 'aircraft': {'registration': 'YRATK', 'typeCode': 'AT7', 'typeName': 'ATR 72', 'ownerAirlineCode': 'RO', 'ownerAirlineName': 'TAROM', 'physicalPaxConfiguration': 'Y072', 'physicalFreightConfiguration': 'PP000LL000', 'operationalConfiguration': 'YBMLGUKQHRNAFTVSEW'}, 'irregularity': {'cancelled': 'N', 'delayCode': [], 'delayReason': [], 'delayDuration': [], 'delayReasonCodePublic': [], 'delayReasonPublicLangTransl': [], 'delayReasonPublic': [], 'delayInformation': []}}]}, {'flightNumber': 2864, 'flightScheduleDate': '2026-01-09', 'id': '20260109+SK+2864', 'route': ['CPH', 'BGO'], 'airline': {'code': 'SK', 'name': 'SCANDINAVIAN AIRLINES SYSTEM (SAS)'}, 'codeShareRelations': [{'marketingFlightNumber': 3316, 'airline': {'code': 'A3', 'name': 'AEGEAN AIRLINES S A'}}, {'marketingFlightNumber': 4579, 'code': 'F', 'type': 'PASSENGER', 'airline': {'code': 'AF', 'name': 'AIR FRANCE'}}, {'marketingFlightNumber': 3942, 'airline': {'code': 'EY', 'name': 'ETIHAD AIRWAYS'}}, {'marketingFlightNumber': 8558, 'airline': {'code': 'KL', 'name': 'KLM ROYAL DUTCH AIRLINES'}}, {'marketingFlightNumber': 5585, 'airline': {'code': 'TP', 'name': 'TAP PORTUGAL'}}], 'flightRelations': {'previousFlightData': {'id': '20260108+SK+2875', 'flightScheduleDate': '2026-01-08', 'airlineCode': 'SK', 'flightNumber': '2875'}}, 'flightStatusPublic': 'ARRIVED', 'flightStatusPublicLangTransl': 'Arrived', 'flightLegs': [{'publishedStatus': 'ARRIVED', 'departureInformation': {'airport': {'code': 'CPH', 'name': 'KASTRUP AIRPORT', 'nameLangTran ...
# Index(['flightNumber', 'flightScheduleDate', 'scheduledFlightId', 'route',
#        'codeShareRelations', 'flightStatusPublic',
#        'flightStatusPublicLangTransl', 'flightLegs', 'airline.code',
#        'airline.name', 'flightRelations.previousFlightData.id',
#        'flightRelations.previousFlightData.flightScheduleDate',
#        'flightRelations.previousFlightData.airlineCode',
#        'flightRelations.previousFlightData.flightNumber', 'haul',
#        'flightRelations.previousFlightData.operationalSuffix',
#        'flightRelations.onwardFlightData.id',
#        'flightRelations.onwardFlightData.flightScheduleDate',
#        'flightRelations.onwardFlightData.airlineCode',
#        'flightRelations.onwardFlightData.flightNumber', 'flightId'],
#       dtype='object')

# %%
# Connect to local postgre instance for dev 
import psycopg2
db_uri = f"postgresql://pierre:data@localhost:5432/dst_db"
conn = psycopg2.connect(db_uri)
cur = conn.cursor()
from sqlalchemy import create_engine
engine = create_engine(db_uri)

# %% [markdown]
# ScheduledFlight and Flight

# %%
# Ingest scheduledFlight table 
df = add_missing_columns(df, "scheduledFlight")
df_scheduled_flight = df[['scheduledFlightId','flightNumber','flightScheduleDate','haul','route','flightStatusPublic','airline.code']]
df_scheduled_flight.columns = ['scheduledFlightId','flightNumber','flightScheduleDate','haul','route','flightStatusPublic','airlineCode']
df_scheduled_flight.\
    to_sql('scheduledFlight', con=engine, if_exists='append', 
           index_label = ['scheduledFlightId','flightNumber','flightScheduleDate','haul','route','flightStatusPublic','airlineCode'],
           index=False)
# Out:
# 100

# %%
# Ingest flight table 
df = add_missing_columns(df, "flight")
flight = df[["flightId","flightNumber","airline.code"]].drop_duplicates() 
flight.columns = ["flightId",'flightNumber','airlineCode']
flight.\
    to_sql('flight', con=engine, if_exists='append',index_label = ["flightId",'flightNumber','airlineCode'], index=False)
# à compléter par les vols de codesharerelations
# Out:
# 100

# %% [markdown]
# codeShareRelations

# %%
# Explode de codeShareRelations en ajoutant un id 
df_codesharerelations = df.codeShareRelations.explode()

# On ajoute l'index pour merger le flightId par la suite et garder le lien entre les codeShareRelations et le flightId
df_codesharerelations['index'] = df_codesharerelations.index
df_codesharerelations = pd.concat([df_codesharerelations, df_codesharerelations.index.to_series()], axis = 1)
df_codesharerelations.columns=["codeShareRelations", "index"]
tmp = df[["flightId"]]
tmp = pd.concat([tmp, tmp.index.to_series()], axis = 1)
tmp.columns=["flightId", "index"]
df_codesharerelations = pd.merge(df_codesharerelations, tmp, on='index', how="left")
del tmp
del df_codesharerelations['index']

tmp = pd.json_normalize(df_codesharerelations['codeShareRelations']) # Unnest le json 
del df_codesharerelations['codeShareRelations']
df_codesharerelations = pd.concat([df_codesharerelations, tmp], axis = 1) # merge le unnest json 
df_codesharerelations = add_missing_columns(df_codesharerelations, "codeShareRelation") 
df_codesharerelations = df_codesharerelations.loc[-df_codesharerelations.marketingFlightNumber.isna()] # retire les lignes sans flightnumber (inutilisables)
df_codesharerelations["relatedFlightId"] = df_codesharerelations["airline.code"] + "+" + df_codesharerelations["marketingFlightNumber"].astype(int).astype(str) # reproduit l'id pour les codeshare
df_codesharerelations["codeShareId"] = df_codesharerelations.apply(lambda row: "+".join(sorted([row["flightId"], row["relatedFlightId"]])) ,axis =1 ) # id unique pour la table 
print(df_codesharerelations.tail())
df_codesharerelations['marketingFlightNumber'] = df_codesharerelations['marketingFlightNumber'].astype(int).astype(str) # convertit la colonne
# Out:
#     flightId  marketingFlightNumber airline.code  \
# 347  DL+5192                 3648.0           KE
# 348  DL+5192                 5706.0           KL
# 349  DL+5192                 7140.0           LA
# 350  DL+5192                 2693.0           VS
# 351  DL+5192                 6428.0           WS
#
#                                           airline.name code type  \
# 347                          KOREAN AIR LINES CO. LTD.  NaN  NaN
# 348                           KLM ROYAL DUTCH AIRLINES  NaN  NaN
# 349  LATAM AIRLINES GROUP S.A. DBA LATAM AIRLINES G...  NaN  NaN
# 350                    VIRGIN ATLANTIC AIRWAYS LIMITED  NaN  NaN
# 351                                            WESTJET  NaN  NaN
#
#     flightScheduleDate      codeShareId relatedFlightId
# 347                NaN  DL+5192+KE+3648         KE+3648
# 348                NaN  DL+5192+KL+5706         KL+5706
# 349                NaN  DL+5192+LA+7140         LA+7140
# 350                NaN  DL+5192+VS+2693         VS+2693
# 351                NaN  DL+5192+WS+6428         WS+6428

# %%
# Ingest flights in flight table --> possible doublons à traiter ensuite 
df_codesharerelations_for_flight = df_codesharerelations[["relatedFlightId", "marketingFlightNumber","airline.code"]].drop_duplicates()
df_codesharerelations_for_flight.columns =  ["flightID",'flightNumber','airlineCode']
df_codesharerelations_for_flight.\
    to_sql('flight', con=engine, if_exists='append',index_label = ["flightID",'flightNumber','airlineCode'], index=False)

# %%
# Ingest codeShareRelation table 
print(df_codesharerelations[["codeShareId" , "flightId","relatedFlightId"]].tail())
df_codesharerelations[["codeShareId" , "flightId","relatedFlightId"]].\
    to_sql('codeShareRelation', con=engine, if_exists='append',index_label = ["codeShareId" , "flightId","relatedFlightId"], index=False)
# Out:
#     relationFlightId flightId relatedFlightId
# 347  DL+5192+KE+3648  DL+5192         KE+3648
# 348  DL+5192+KL+5706  DL+5192         KL+5706
# 349  DL+5192+LA+7140  DL+5192         LA+7140
# 350  DL+5192+VS+2693  DL+5192         VS+2693
# 351  DL+5192+WS+6428  DL+5192         WS+6428
# 330

# %% [markdown]
# flightRelation

# %%
# Fonction pour traiter les trois types de relations 
def create_relation_df(relationtype, df):
    cols_ = [col for col in df if col.startswith(f'flightRelations.{relationtype}')] # récupère les colonnes de ce type de relations 
    cols_.append("scheduledFlightId") # ajoute l'id 
    # ici la fonction pour vérifier que toutes les colonnes sont là 
    df = add_missing_columns(df, "flightRelation") 

    df_relations = df[cols_]
    df_relations.insert( df_relations.shape[1], "relationType", f"{relationtype}") # ajoute la colonne qui décrit le type 
    try:
        df_relations = df_relations.loc[-df_relations[f'flightRelations.{relationtype}FlightData.id'].isna()] # retire les lignes vides 
        df_relations["flightRelationId"] = df_relations[f"flightRelations.{relationtype}FlightData.id"] + "+" + df_relations["scheduledFlightId"] # id pour les relations 
        df_relations = df_relations[["flightRelationId","scheduledFlightId",f"flightRelations.{relationtype}FlightData.id","relationType"]] 
        df_relations.columns = ["flightRelationId","scheduledFlightId","relatedScheduledFlightId","relationType"]
    except:
        # df vide si des colonnes sont manquantes 
        df_relations = pd.DataFrame({c: pd.Series(dtype=t) for c, t in {'flightRelationId': 'str', 
                                                                        'scheduledFlightId':"str",
                                                                        'relatedScheduledFlightId': 'str',
                                                                          'relationType': 'str'}.items()})

        pass

    return df_relations

# %%
# Applique la fonction 
df_previousrelations = create_relation_df("previous",df)
df_equivalentrelations = create_relation_df("equivalent",df)
df_onwardrelations = create_relation_df("onward",df)
df_onwardrelations.head()
# Out:
#                      flightRelationId scheduledFlightId  \
# 16  20260109+KL+1080+20260109+KL+1079  20260109+KL+1079
#
#    relatedScheduledFlightId relationType
# 16         20260109+KL+1080       onward

# %%
# Ingest flightRelation table 
df_previousrelations.\
    to_sql('flightRelation', con=engine, if_exists='append',index_label = ["flightRelationId","scheduledFlightId","relatedScheduledFlightId","relationType"], index=False)
df_equivalentrelations.\
    to_sql('flightRelation', con=engine, if_exists='append',index_label = ["flightRelationId","scheduledFlightId","relatedScheduledFlightId","relationType"], index=False)
df_onwardrelations.\
    to_sql('flightRelation', con=engine, if_exists='append',index_label = ["flightRelationId","scheduledFlightId","relatedScheduledFlightId","relationType"], index=False)
# Out:
# 1

# %% [markdown]
# flightLegs

# %%
# Unnest le champ flightLegs 
df_legs = df.flightLegs.explode() # recupère le champ 
# Récupère l'index pour conserver le lien avec le scheduledFlight
df_legs['index'] = df_legs.index

df_legs = pd.concat([df_legs, df_legs.index.to_series()], axis = 1)
df_legs.columns=["flightLegs", "index"]
tmp = df[["scheduledFlightId"]]
tmp = pd.concat([tmp, tmp.index.to_series()], axis = 1)
tmp.columns=["scheduledFlightId", "index"]
df_legs = pd.merge(df_legs, tmp, on='index', how="left")
del tmp
del df_legs['index']
tmp = pd.json_normalize(df_legs['flightLegs']) # unnest le champ 
del df_legs['flightLegs']
df_legs = pd.concat([df_legs, tmp], axis = 1)
df_legs = add_missing_columns(df_legs, "flightLeg") 
df_legs["flightLegId"] = df_legs["scheduledFlightId"] + "+" + df_legs["departureInformation.airport.code"] + "+" + df_legs["arrivalInformation.airport.code"] # créé l'id 

# ici la fonction pour vérifier que toutes les colonnes sont là

# %%
df_legs["flightLegId"] = df_legs["scheduledFlightId"] + "+" + df_legs["departureInformation.airport.code"] + "+" + df_legs["arrivalInformation.airport.code"] # créé l'id 
df_legs_ = df_legs[["flightLegId",
        "scheduledFlightId",
        "legStatusPublicLangTransl",
        "statusName",
        "passengerCustomsStatus",
        "serviceType",
        "serviceTypeName",
        "restricted",
        "scheduledFlightDuration",
        "departureDateTimeDifference",
        "arrivalDateTimeDifference",
        "timeToArrival",
        "completionPercentage",
        "timeZoneDifference",
        "aircraft.typeCode",
        "DepartureInformation.airport.places.aerogareCode", 
        "DepartureInformation.airport.places.gateNumber" ,
        "DepartureInformation.airport.places.parkingPosition" ,
        "DepartureInformation.airport.places.parkingPositionCustomStatus", 
        "DepartureInformation.airport.places.parkingPositionType", 
        "DepartureInformation.airport.places.pierCode" ,
        "DepartureInformation.airport.places.terminalCode", 
        "DepartureInformation.airport.code" ,
        "DepartureInformation.times.actual" ,
        "DepartureInformation.times.latestPublished", 
        "DepartureInformation.times.modified",
        "DepartureInformation.times.scheduled" ,
        "DepartureInformation.airport.places.boardingContactType", 
        "DepartureInformation.airport.places.boardingPier ",
        "DepartureInformation.airport.places.boardingTerminal", 
        "DepartureInformation.airport.places.checkInAerogare", 
        "DepartureInformation.airport.places.checkInZone", 
        "DepartureInformation.airport.places.departureTerminal" ,
        "DepartureInformation.airport.places.paxDepartureGate" ,
        "DepartureInformation.boardingTimes.actualBoardingOpen", 
        "DepartureInformation.boardingTimes.firstPaxBoarding", 
        "DepartureInformation.boardingTimes.gateCloseTime" ,
        "DepartureInformation.boardingTimes.plannedBoardingTime", 
        "DepartureInformation.times.actualTakeOffTime", 
        "DepartureInformation.times.estimatedPublic" ,
        "DepartureInformation.times.estimatedTakeOffTime",
        "arrivalInformation.airport.places.aerogareCode", 
        "arrivalInformation.airport.places.gateNumber" ,
        "arrivalInformation.airport.places.parkingPosition" ,
        "arrivalInformation.airport.places.parkingPositionCustomStatus", 
        "arrivalInformation.airport.places.parkingPositionType", 
        "arrivalInformation.airport.places.pierCode" ,
        "arrivalInformation.airport.places.terminalCode" ,
        "arrivalInformation.airport.code" ,
        "arrivalInformation.times.actual" ,
        "arrivalInformation.times.latestPublished", 
        "arrivalInformation.times.modified" ,
        "arrivalInformation.times.scheduled", 
        "arrivalInformation.airport.places.arrivalHall" ,
        "arrivalInformation.airport.places.arrivalPositionPier" ,
        "arrivalInformation.airport.places.arrivalPositionTerminal", 
        "arrivalInformation.airport.places.arrivalTerminal" ,
        "arrivalInformation.airport.places.baggageBelt" ,
        "arrivalInformation.airport.places.disembarkingAerogare" ,
        "arrivalInformation.airport.places.disembarkingBusQuantity" ,
        "arrivalInformation.airport.places.disembarkingContactType", 
        "arrivalInformation.airport.places.expectedBagOnBeltTime", 
        "arrivalInformation.airport.places.firstBagOnBeltTime" ,
        "arrivalInformation.airport.places.lastBagOnBeltTime" ,
        "arrivalInformation.times.actualTouchDownTime" ,
        "arrivalInformation.times.estimated.value" ,
        "arrivalInformation.times.estimatedArrival" ,
        "arrivalInformation.times.estimatedTouchDownTime"
]]

df_legs_.columns = ["flightLegId",
         "scheduledFlightId",
         "legStatus",
         "status",
         "passengerCustomStatus",
        "serviceType",
        "serviceTypeName",
        "restricted",
        "scheduledFlightDuration",
        "departureDateTimeDifference",
        "arrivalDateTimeDifference",
        "timeToArrival",
        "completionPercentage",
        "timeZoneDifference",
        "aircraftCode",
        "departureAerogareCode" ,
        "departureGateNumber" ,
        "departureParkingPosition", 
        "departureParkingPositionCustomStatus" ,
        "departureParkingPositionType" ,
        "departurePierCode" ,
        "departureTerminalCode", 
        "departureAirportCode" ,
        "departureActualTime"  ,
        "departureLatestPublishedTime",  
        "departureModifiedTime"  ,
        "departureScheduledTime"  ,
        "departureBoardingContactType", 
        "departureBoardingPier" ,
        "departureBoardingTerminal", 
        "departureCheckInAerogare" ,
        "departureCheckInZone" ,
        "departureTerminal" ,
        "departurePaxDepartureGate", 
        "departureActualBoardingOpen", 
        "departureFirstPaxBoarding" ,
        "departureGateCloseTime" ,
        "departurePlannedBoardingTime", 
        "departureActualTakeOffTime" ,
        "departureEstimatedPublic" ,
        "departureEstimatedTakeOffTime", 
        "arrivalAerogareCode", 
"arrivalGateNumber" ,
"arrivalParkingPosition" ,
"arrivalParkingPositionCustomStatus", 
"arrivalParkingPositionType", 
"arrivalPierCode" ,
"arrivalTerminalCode" ,
"arrivalAirportCode" ,
"arrivalActualTime" ,
"arrivalLatestPublishedTime", 
"arrivalModifiedTime" ,
"arrivalScheduledTime", 
"arrivalHall" ,
"arrivalPositionPier" ,
"arrivalPositionTerminal", 
"arrivalTerminal" ,
"arrivalBaggageBelt" ,
"arrivalDisembarkingAerogare" ,
"arrivalDisembarkingBusQuantity" ,
"arrivalDisembarkingContactType", 
"arrivalExpectedBagOnBeltTime", 
"arrivalFirstBagOnBeltTime" ,
"arrivalLastBagOnBeltTime" ,
"arrivalActualTouchDownTime" ,
"arrivalEstimated" ,
"arrivalEstimatedArrival" ,
"arrivalEstimatedTouchDownTime", 
         ]

  
df_legs_.\
    to_sql('flightLeg', con=engine, if_exists='append',index=False)
# Out:
# 122

# %% [markdown]
# Airport

# %%
# On joint les infos sur les airports de départs et arrivées 
df_legs = add_missing_columns(df_legs, "airport") 

df_departure_airport = df_legs[[
    "departureInformation.airport.code",
    "departureInformation.airport.name",
    "departureInformation.airport.location.latitude",
    "departureInformation.airport.location.longitude",
    "departureInformation.airport.city.code"
                                ]]
df_arrival_airport = df_legs[[
    "arrivalInformation.airport.code",
    "arrivalInformation.airport.name",
    "arrivalInformation.airport.location.latitude",
    "arrivalInformation.airport.location.longitude",
    "arrivalInformation.airport.city.code"
                                ]]
df_departure_airport.columns = [
  "airportCode",
  "airportName", 
  "latitude" ,
  "longitude", 
  "cityCode", 
]
df_arrival_airport.columns = [
  "airportCode",
  "airportName", 
  "latitude" ,
  "longitude", 
  "cityCode", 
]
df_airport = pd.concat([df_departure_airport,df_arrival_airport],axis=0).drop_duplicates()

df_airport.\
    to_sql('airport', con=engine, if_exists='append',
           index_label = [
  "airportCode",
  "airportName", 
  "latitude" ,
  "longitude", 
  "cityCode", 
], 
           index=False)
# Out:
# 111

# %% [markdown]
# City

# %%
# On joint les infos sur les cities de départs et arrivées 
df_legs = add_missing_columns(df_legs, "city") 

df_departure_city = df_legs[[
    "departureInformation.airport.city.code",
    "departureInformation.airport.city.name",
    "departureInformation.airport.city.country.code"
                                ]]
df_arrival_city = df_legs[[
        "arrivalInformation.airport.city.code",
    "arrivalInformation.airport.city.name",
    "arrivalInformation.airport.city.country.code"

                                ]]
df_departure_city.columns = [
  "cityCode",
  "cityName", 
  "countryCode" 
]
df_arrival_city.columns = [
  "cityCode",
  "cityName", 
  "countryCode" 
]



df_city = pd.concat([df_departure_city,df_arrival_city],axis=0).drop_duplicates()

df_city.\
    to_sql('city', con=engine, if_exists='append',
           index_label = [
  "cityCode",
  "cityName", 
  "countryCode" 
], 
           index=False)
# Out:
# 107

# %% [markdown]
# Country

# %%
# On joint les infos sur les countries de départs et arrivées 
df_legs = add_missing_columns(df_legs, "country") 


df_departure_country = df_legs[[
    "departureInformation.airport.city.country.code",
    "departureInformation.airport.city.country.name",
"departureInformation.airport.city.country.euroCountry",
   "departureInformation.airport.city.country.euCountry",
   "departureInformation.airport.city.country.areaCode"
                                ]]
df_arrival_country = df_legs[[
    "arrivalInformation.airport.city.country.code",
    "arrivalInformation.airport.city.country.name",
"arrivalInformation.airport.city.country.euroCountry",
   "arrivalInformation.airport.city.country.euCountry",
   "arrivalInformation.airport.city.country.areaCode"
                                ]]
df_departure_country.columns = [
  "countryCode" ,
  "countryName",
    "euroCountry" ,
  "euCountry" ,
  "areaCode" 
]
df_arrival_country.columns = [
  "countryCode" ,
  "countryName",
    "euroCountry" ,
  "euCountry" ,
  "areaCode" 
]



df_country = pd.concat([df_departure_country,df_arrival_country],axis=0).drop_duplicates()

df_country.\
    to_sql('country', con=engine, if_exists='append',
           index_label = [
  "countryCode" ,
  "countryName",
    "euroCountry" ,
  "euCountry" ,
  "areaCode" 
], 
           index=False)
# Out:
# 37

# %% [markdown]
# Aircraft

# %%
df_legs = add_missing_columns(df_legs, "aircraft") 

df_aircraft = df_legs[[
"aircraft.typeCode",
"aircraft.typeName",
"aircraft.ownerAirlineCode",
"aircraft.physicalPaxConfiguration",
"aircraft.physicalFreightConfiguration",
"aircraft.operationalConfiguration",
"aircraft.cockpitCrewEmployer",
"aircraft.cabinCrewEmployer",
"aircraft.registration",
"aircraft.saleableConfiguration",
"aircraft.subFleetCodeId",
"aircraft.typeCode",
"aircraft.typeName",
]].drop_duplicates()
df_aircraft.head()

df_aircraft.columns = [
  "aircraftCode" ,
  "aircraftName" ,
  "ownerAirlineCode", 
  "physicalPaxConfiguration", 
  "physicalFreightConfiguration", 
  "operationalConfiguration" ,
  "cockpitCrewEmployerCode" ,
  "cabinCrewEmployerCode" ,
  "registration" ,
  "saleableConfiguration" ,
  "subFleetCodeId" ,
  "typeCode" ,
  "typeName" 
]

df_aircraft.\
    to_sql('aircraft', con=engine, if_exists='append',
           index_label = [
  "aircraftCode" ,
  "aircraftName" ,
  "ownerAirlineCode", 
  "physicalPaxConfiguration", 
  "physicalFreightConfiguration", 
  "operationalConfiguration" ,
  "cockpitCrewEmployerCode" ,
  "cabinCrewEmployerCode" ,
  "registration" ,
  "saleableConfiguration" ,
  "subFleetCodeId" ,
  "typeCode" ,
  "typeName" 
], 
           index=False)
# Out:
# 86

# %% [markdown]
# Irregularities

# %%
# add missing columns 
df_legs = add_missing_columns(df_legs, "irregularity") 
df_legs = add_missing_columns(df_legs, "delay") 
df_legs = add_missing_columns(df_legs, "cancellationReason") 
df_legs = add_missing_columns(df_legs, "delayReason") 

df_legs = df_legs.loc[-df_legs.flightLegId.isna()] # retire les lignes sans flightnumber (inutilisables)

# %%
#  convert list to values
df_legs['irregularity.delayCode'] = df_legs['irregularity.delayCode'].apply(lambda x:x[0] if len(x)>0 else "")
df_legs['irregularity.delayDuration'] = df_legs['irregularity.delayDuration'].apply(lambda x:x[0] if len(x)>0 else "00")
df_legs['irregularity.delayReasonCodePublic'] = df_legs['irregularity.delayReasonCodePublic'].apply(lambda x:x[0] if len(x)>0 else "")
df_legs['irregularity.delayReasonPublicLangTransl'] = df_legs['irregularity.delayReasonPublicLangTransl'].apply(lambda x:x[0] if len(x)>0 else "")

# %%
# get columns 
df_irregularity = df_legs[["flightLegId",
 'irregularity.cancelled',
 "irregularity.cancellationReasonCodePublic",
'irregularity.delayCode',
"irregularity.delayDuration"]].drop_duplicates()
df_delay = df_legs[['irregularity.delayCode',"irregularity.delayReasonCodePublic"]].drop_duplicates() # attention, voir si c'est unique
df_cancelreason = df_legs[["irregularity.cancellationReasonCodePublic",
"irregularity.cancellationReasonPublicShort",
"irregularity.cancellationReasonPublicLong"]].drop_duplicates()
df_delayreason = df_legs[["irregularity.delayReasonCodePublic", 
                "irregularity.delayReasonPublicLangTransl"]].drop_duplicates()

# change columns names 
df_irregularity.columns = ["flightLegId","cancelled","cancellationReasonCode","delayCode","delayDuration"]
df_delay.columns = ["delayCode","delayReasonCode"]
df_cancelreason.columns = ["cancellationReasonCode","cancellationReasonShort","cancellationReasonLong"]
df_delayreason.columns = ["delayReasonCode", "delayReason"]

# %%
df_irregularity.\
    to_sql('irregularity', con=engine, if_exists='append',
           index_label = ["flightLegId","cancelled","cancellationReasonCode","delayCode","delayDuration"], 
           index=False)
df_delay.\
    to_sql('delay', con=engine, if_exists='append',
           index_label = ["delayCode","delayReasonCode"],
           index=False)

df_cancelreason.\
    to_sql('cancelReason', con=engine, if_exists='append',
           index_label = ["cancellationReasonCode","cancellationReasonShort","cancellationReasonLong"],
           index=False)

df_delayreason.\
    to_sql('delayReason', con=engine, if_exists='append',
           index_label = ["delayReasonCode", "delayReason"],
           index=False)
# Out:
# 6
